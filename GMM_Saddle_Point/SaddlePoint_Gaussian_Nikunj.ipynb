# %%
#Importing the required libraries
import numpy as np
import matplotlib.pyplot as plt
import scipy
import sympy as smp 
from sympy import *
from sympy import Eq, Symbol, solve
from scipy import stats
import math as mt


x=Symbol('x')
y=Symbol('y')
u=Symbol('u')
s=Symbol('s')

y=1/(5*smp.sqrt(2*np.pi)) * smp.exp(-((x-1)**2)/(2*5**2))
#print(y)

dy=y.diff(x)
#print(dy)
s=solve(dy)
#print(s)

ddy=dy.diff(x)
#print(ddy)

z=ddy.subs(x,s)
#print(z)

# Plotting the graph  
smp.plotting.plot(y)
smp.plotting.plot(dy)
smp.plotting.plot(ddy)

plt.grid('on')
saddle_point=0
mean=0
stdv=3.75
x = np.linspace(-10,10,1000)
print('Shape of x :',x.shape)

y = np.exp(-((x-mean)**2)/(2*stdv**2)) * (1/(stdv*np.sqrt(2*np.pi)))
dy= np.exp(-((x-mean)**2)/(2*stdv**2)) * (1/(stdv*np.sqrt(2*np.pi))) *((x-mean)/stdv**2)
ddy = np.exp(-((x-mean)**2)/(2*stdv**2)) * ((1)/(stdv**3*np.sqrt(2*np.pi))) * (((x-mean)/stdv)**2 - stdv)
plt.plot(x,y)
plt.plot(x,dy)
plt.plot(x,ddy)

z=np.amax(y)
#print(z)
for i in range(len(x)):
  dy= np.exp(-((x[i]-mean)**2)/(2*stdv**2)) * (1/(stdv*np.sqrt(2*np.pi))) *((x[i]-mean)/stdv**2)
  if dy==0:
    saddle_point=x[i]
    break

print('Saddle Point :', saddle_point)
# Out:
# Shape of x : (1000,)
# Saddle Point : 0

# %%
#Importing the required libraries
import numpy as np
import matplotlib.pyplot as plt
import scipy
import sympy as smp 
from sympy import *
from sympy import Eq, Symbol, solve
from scipy import stats
import math as mt

# Plotting the graph
plt.grid('on')
saddle_point=0
mean = 3
stdv = 5
x = np.linspace(-10,10,1000)
print('Shape of x :',x.shape)
y = np.exp(-((x-mean)**2)/(2*stdv**2)) * (1/(stdv*np.sqrt(2*np.pi)))
dy= np.exp(-((x-mean)**2)/(2*stdv**2)) * (1/(stdv*np.sqrt(2*np.pi))) *((x-mean)/stdv**2)
ddy = np.exp(-((x-mean)**2)/(2*stdv**2)) * ((1)/(stdv**3*np.sqrt(2*np.pi))) * (((x-mean)/stdv)**2 - stdv)
plt.plot(x,y)
plt.plot(x,dy)
plt.plot(x,ddy)

z=np.amax(y)
#print(z)
for i in range(len(x)):
  dy= np.exp(-((x[i]-mean)**2)/(2*stdv**2)) * (1/(stdv*np.sqrt(2*np.pi))) *((x[i]-mean)/stdv**2)
  if dy==0:
    saddle_point=x[i]
    break
print('Saddle Point :', saddle_point)
# Out:
# Shape of x : (1000,)
# Saddle Point : 0
